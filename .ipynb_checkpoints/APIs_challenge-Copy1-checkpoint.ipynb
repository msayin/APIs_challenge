# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 637

# %%
#base_url = "https://openweathermap.org/api"
base_url = "http://api.openweathermap.org/data/2.5/weather?"

df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])

print("Beginning Data Retrieval\n"   
"-----------------------------")
     
index=0
cnt=0
for city_name in cities :
    cnt=cnt+1
    #city_name='fairbanks'
    complete_url = base_url + "q=" + city_name + "&appid=580fd7448251c23055ceb1ffd2a30535" #+ api_keys.api_key
    print("Processing Record " + str(cnt) + " of Set " + str(len(cities)) + " | " + city_name)
    # get method of requests module 
    # return response object 
    response = requests.get(complete_url) 

    # json method of response object  
    # convert json format data into 
    # python format data 
    x = response.json() 
    #print(x.items())
    
    # Now x contains list of nested dictionaries 
    # Check the value of "cod" key is equal to 
    # "404", means city is found otherwise, 
    # city is not found 
    if x["cod"] != "404": 
        # store the value of "main" 
        # key in variable y 
        y = x["main"] 
        
        df.set_value(index, "City", x["name"])
        df.set_value(index, "Cloudiness", x["clouds"]["all"])
        df.set_value(index, "Country", x["sys"]["country"])
        df.set_value(index, "Date", x["dt"])
        df.set_value(index, "Max Temp", x["main"]["temp_max"])
        df.set_value(index, "Wind Speed", x["wind"]["speed"])
        df.set_value(index, "Lat", x["coord"]["lat"])
        df.set_value(index, "Lng", x["coord"]["lon"])
        df.set_value(index, "Humidity", x["main"]["humidity"])
        index = index +1         
    else:     
        print("City not found. Skipping...")

print("-----------------------------\n"
"Data Retrieval Complete\n"
"-----------------------------")

df.to_csv(output_data_file, index=False)

df.head()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 637 | new norfolk
# Processing Record 2 of Set 637 | vaini
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:37: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:38: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:40: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\fmsay\Miniconda3\lib\site-packages\ipykernel_launcher.py:45: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 3 of Set 637 | cape town
# Processing Record 4 of Set 637 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 637 | praxedis guerrero
# Processing Record 6 of Set 637 | khatanga
# Processing Record 7 of Set 637 | busselton
# Processing Record 8 of Set 637 | harbour breton
# Processing Record 9 of Set 637 | katsuura
# Processing Record 10 of Set 637 | rikitea
# Processing Record 11 of Set 637 | deputatskiy
# Processing Record 12 of Set 637 | kondopoga
# Processing Record 13 of Set 637 | mataura
# Processing Record 14 of Set 637 | kavieng
# Processing Record 15 of Set 637 | turbat
# Processing Record 16 of Set 637 | senador jose porfirio
# Processing Record 17 of Set 637 | koulamoutou
# Processing Record 18 of Set 637 | athabasca
# Processing Record 19 of Set 637 | berlevag
# Processing Record 20 of Set 637 | zaragoza
# Processing Record 21 of Set 637 | hermanus
# Processing Record 22 of Set 637 | biak
# Processing Record 23 of Set 637 | qui nhon
# City not found. Skipping...
# Processing Record 24 of Set 637 | port blair
# Processing Record 25 of Set 637 | bredasdorp
# Processing Record 26 of Set 637 | nizhniy tsasuchey
# Processing Record 27 of Set 637 | ahipara
# Processing Record 28 of Set 637 | alofi
# Processing Record 29 of Set 637 | ushuaia
# Processing Record 30 of Set 637 | nikolskoye
# Processing Record 31 of Set 637 | saint-augustin
# Processing Record 32 of Set 637 | ust-nera
# Processing Record 33 of Set 637 | barrow
# Processing Record 34 of Set 637 | iisalmi
# Processing Record 35 of Set 637 | geraldton
# Processing Record 36 of Set 637 | yar-sale
# Processing Record 37 of Set 637 | rawson
# Processing Record 38 of Set 637 | port alfred
# Processing Record 39 of Set 637 | east london
# Processing Record 40 of Set 637 | hofn
# Processing Record 41 of Set 637 | torbay
# Processing Record 42 of Set 637 | puri
# Processing Record 43 of Set 637 | egvekinot
# Processing Record 44 of Set 637 | mashhad
# Processing Record 45 of Set 637 | pangnirtung
# Processing Record 46 of Set 637 | chapais
# Processing Record 47 of Set 637 | albany
# Processing Record 48 of Set 637 | cidreira
# Processing Record 49 of Set 637 | avarua
# Processing Record 50 of Set 637 | vardo
# Processing Record 51 of Set 637 | muros
# Processing Record 52 of Set 637 | mangrol
# Processing Record 53 of Set 637 | cap malheureux
# Processing Record 54 of Set 637 | arraial do cabo
# Processing Record 55 of Set 637 | bluff
# Processing Record 56 of Set 637 | abnub
# Processing Record 57 of Set 637 | punta arenas
# Processing Record 58 of Set 637 | atuona
# Processing Record 59 of Set 637 | saint-philippe
# Processing Record 60 of Set 637 | tasiilaq
# Processing Record 61 of Set 637 | adwa
# Processing Record 62 of Set 637 | chokurdakh
# Processing Record 63 of Set 637 | oranjemund
# Processing Record 64 of Set 637 | san policarpo
# Processing Record 65 of Set 637 | attawapiskat
# City not found. Skipping...
# Processing Record 66 of Set 637 | esperance
# Processing Record 67 of Set 637 | pisco
# Processing Record 68 of Set 637 | meyungs
# City not found. Skipping...
# Processing Record 69 of Set 637 | ayagoz
# Processing Record 70 of Set 637 | buala
# Processing Record 71 of Set 637 | westerland
# Processing Record 72 of Set 637 | butaritari
# Processing Record 73 of Set 637 | batagay-alyta
# Processing Record 74 of Set 637 | omboue
# Processing Record 75 of Set 637 | shimoda
# Processing Record 76 of Set 637 | kirillov
# Processing Record 77 of Set 637 | meulaboh
# Processing Record 78 of Set 637 | vanimo
# Processing Record 79 of Set 637 | salalah
# Processing Record 80 of Set 637 | lebu
# Processing Record 81 of Set 637 | saint george
# Processing Record 82 of Set 637 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 83 of Set 637 | provideniya
# Processing Record 84 of Set 637 | joao pinheiro
# Processing Record 85 of Set 637 | xining
# Processing Record 86 of Set 637 | barentsburg
# City not found. Skipping...
# Processing Record 87 of Set 637 | gunnedah
# Processing Record 88 of Set 637 | mount isa
# Processing Record 89 of Set 637 | abha
# Processing Record 90 of Set 637 | margate
# Processing Record 91 of Set 637 | cabo san lucas
# Processing Record 92 of Set 637 | taolanaro
# City not found. Skipping...
# Processing Record 93 of Set 637 | dzilam gonzalez
# Processing Record 94 of Set 637 | jamestown
# Processing Record 95 of Set 637 | muriti
# Processing Record 96 of Set 637 | castro
# Processing Record 97 of Set 637 | belushya guba
# City not found. Skipping...
# Processing Record 98 of Set 637 | portland
# Processing Record 99 of Set 637 | suamico
# Processing Record 100 of Set 637 | brasileia
# City not found. Skipping...
# Processing Record 101 of Set 637 | bontang
# Processing Record 102 of Set 637 | kahului
# Processing Record 103 of Set 637 | kapaa
# Processing Record 104 of Set 637 | sumbawanga
# Processing Record 105 of Set 637 | owo
# Processing Record 106 of Set 637 | lasa
# Processing Record 107 of Set 637 | kaitangata
# Processing Record 108 of Set 637 | carnarvon
# Processing Record 109 of Set 637 | umm kaddadah
# Processing Record 110 of Set 637 | isangel
# Processing Record 111 of Set 637 | sentyabrskiy
# City not found. Skipping...
# Processing Record 112 of Set 637 | sokna
# Processing Record 113 of Set 637 | shubarshi
# Processing Record 114 of Set 637 | grand gaube
# Processing Record 115 of Set 637 | jonkoping
# Processing Record 116 of Set 637 | aleksandrov gay
# Processing Record 117 of Set 637 | kapoeta
# City not found. Skipping...
# Processing Record 118 of Set 637 | acapulco
# Processing Record 119 of Set 637 | mananjary
# Processing Record 120 of Set 637 | talnakh
# Processing Record 121 of Set 637 | phuket
# Processing Record 122 of Set 637 | evensk
# Processing Record 123 of Set 637 | zurrieq
# Processing Record 124 of Set 637 | mahebourg
# Processing Record 125 of Set 637 | hithadhoo
# Processing Record 126 of Set 637 | amderma
# City not found. Skipping...
# Processing Record 127 of Set 637 | gibraleon
# Processing Record 128 of Set 637 | upernavik
# Processing Record 129 of Set 637 | hasaki
# Processing Record 130 of Set 637 | zachepylivka
# Processing Record 131 of Set 637 | klaksvik
# Processing Record 132 of Set 637 | general roca
# Processing Record 133 of Set 637 | babanka
# Processing Record 134 of Set 637 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 135 of Set 637 | nguiu
# City not found. Skipping...
# Processing Record 136 of Set 637 | ponta do sol
# Processing Record 137 of Set 637 | redlands
# Processing Record 138 of Set 637 | bethel
# Processing Record 139 of Set 637 | keningau
# Processing Record 140 of Set 637 | hobart
# Processing Record 141 of Set 637 | kruisfontein
# Processing Record 142 of Set 637 | qaanaaq
# Processing Record 143 of Set 637 | damara
# Processing Record 144 of Set 637 | sao jose da coroa grande
# Processing Record 145 of Set 637 | ilulissat
# Processing Record 146 of Set 637 | fukue
# Processing Record 147 of Set 637 | tamiahua
# Processing Record 148 of Set 637 | algeciras
# Processing Record 149 of Set 637 | ambilobe
# Processing Record 150 of Set 637 | hilo
# Processing Record 151 of Set 637 | puerto ayora
# Processing Record 152 of Set 637 | kodiak
# Processing Record 153 of Set 637 | iquique
# Processing Record 154 of Set 637 | manokwari
# Processing Record 155 of Set 637 | ngukurr
# City not found. Skipping...
# Processing Record 156 of Set 637 | kemin
# Processing Record 157 of Set 637 | krasnoselkup
# City not found. Skipping...
# Processing Record 158 of Set 637 | minbu
# Processing Record 159 of Set 637 | pinhao
# Processing Record 160 of Set 637 | mahibadhoo
# Processing Record 161 of Set 637 | puerto escondido
# Processing Record 162 of Set 637 | taltal
# Processing Record 163 of Set 637 | narsaq
# Processing Record 164 of Set 637 | catabola
# Processing Record 165 of Set 637 | bandarbeyla
# Processing Record 166 of Set 637 | yulara
# Processing Record 167 of Set 637 | flin flon
# Processing Record 168 of Set 637 | port elizabeth
# Processing Record 169 of Set 637 | saldanha
# Processing Record 170 of Set 637 | zeya
# Processing Record 171 of Set 637 | nador
# Processing Record 172 of Set 637 | saint anthony
# Processing Record 173 of Set 637 | fairbanks
# Processing Record 174 of Set 637 | thompson
# Processing Record 175 of Set 637 | souillac
# Processing Record 176 of Set 637 | roald
# Processing Record 177 of Set 637 | sola
# Processing Record 178 of Set 637 | emerald
# Processing Record 179 of Set 637 | lamar
# Processing Record 180 of Set 637 | angra dos reis
# Processing Record 181 of Set 637 | naze
# Processing Record 182 of Set 637 | vestmannaeyjar
# Processing Record 183 of Set 637 | yelan-kolenovskiy
# Processing Record 184 of Set 637 | smithers
# Processing Record 185 of Set 637 | yellowknife
# Processing Record 186 of Set 637 | nuuk
# Processing Record 187 of Set 637 | nongstoin
# Processing Record 188 of Set 637 | cabra
# Processing Record 189 of Set 637 | san patricio
# Processing Record 190 of Set 637 | paamiut
# Processing Record 191 of Set 637 | monroe
# Processing Record 192 of Set 637 | stokmarknes
# Processing Record 193 of Set 637 | samusu
# City not found. Skipping...
# Processing Record 194 of Set 637 | tarko-sale
# Processing Record 195 of Set 637 | coron
# Processing Record 196 of Set 637 | muisne
# Processing Record 197 of Set 637 | conchagua
# Processing Record 198 of Set 637 | tumannyy
# City not found. Skipping...
# Processing Record 199 of Set 637 | ribeira grande
# Processing Record 200 of Set 637 | boa vista
# Processing Record 201 of Set 637 | rosa zarate
# Processing Record 202 of Set 637 | haines junction
# Processing Record 203 of Set 637 | ossora
# Processing Record 204 of Set 637 | mar del plata
# Processing Record 205 of Set 637 | hay river
# Processing Record 206 of Set 637 | sabang
# Processing Record 207 of Set 637 | rungata
# City not found. Skipping...
# Processing Record 208 of Set 637 | pevek
# Processing Record 209 of Set 637 | dikson
# Processing Record 210 of Set 637 | ostrovnoy
# Processing Record 211 of Set 637 | preobrazheniye
# Processing Record 212 of Set 637 | bathsheba
# Processing Record 213 of Set 637 | saint-pierre
# Processing Record 214 of Set 637 | mys shmidta
# City not found. Skipping...
# Processing Record 215 of Set 637 | burkhala
# City not found. Skipping...
# Processing Record 216 of Set 637 | lavrentiya
# Processing Record 217 of Set 637 | lensk
# Processing Record 218 of Set 637 | sorland
# Processing Record 219 of Set 637 | aykhal
# Processing Record 220 of Set 637 | half moon bay
# Processing Record 221 of Set 637 | urdzhar
# City not found. Skipping...
# Processing Record 222 of Set 637 | tazovskiy
# Processing Record 223 of Set 637 | ishinomaki
# Processing Record 224 of Set 637 | fortuna
# Processing Record 225 of Set 637 | hualmay
# Processing Record 226 of Set 637 | bambous virieux
# Processing Record 227 of Set 637 | minamiashigara
# Processing Record 228 of Set 637 | bilibino
# Processing Record 229 of Set 637 | houma
# Processing Record 230 of Set 637 | bindi
# Processing Record 231 of Set 637 | samalaeulu
# City not found. Skipping...
# Processing Record 232 of Set 637 | teahupoo
# Processing Record 233 of Set 637 | cherskiy
# Processing Record 234 of Set 637 | dunedin
# Processing Record 235 of Set 637 | oistins
# Processing Record 236 of Set 637 | tuktoyaktuk
# Processing Record 237 of Set 637 | mastic beach
# Processing Record 238 of Set 637 | saskylakh
# Processing Record 239 of Set 637 | tandil
# Processing Record 240 of Set 637 | tumauini
# Processing Record 241 of Set 637 | nizhneyansk
# City not found. Skipping...
# Processing Record 242 of Set 637 | qinhuangdao
# Processing Record 243 of Set 637 | tigil
# Processing Record 244 of Set 637 | jiuquan
# Processing Record 245 of Set 637 | volot
# Processing Record 246 of Set 637 | maragogi
# Processing Record 247 of Set 637 | pecanha
# Processing Record 248 of Set 637 | laurinburg
# Processing Record 249 of Set 637 | malangali
# Processing Record 250 of Set 637 | vangaindrano
# Processing Record 251 of Set 637 | kalianget
# Processing Record 252 of Set 637 | rabaul
# Processing Record 253 of Set 637 | mujiayingzi
# Processing Record 254 of Set 637 | kamthi
# City not found. Skipping...
# Processing Record 255 of Set 637 | pechenga
# Processing Record 256 of Set 637 | dhidhdhoo
# Processing Record 257 of Set 637 | codrington
# Processing Record 258 of Set 637 | kitimat
# Processing Record 259 of Set 637 | camana
# City not found. Skipping...
# Processing Record 260 of Set 637 | louisbourg
# City not found. Skipping...
# Processing Record 261 of Set 637 | pangody
# Processing Record 262 of Set 637 | cap-aux-meules
# Processing Record 263 of Set 637 | hornepayne
# Processing Record 264 of Set 637 | santa maria
# Processing Record 265 of Set 637 | chiriqui grande
# Processing Record 266 of Set 637 | ketchikan
# Processing Record 267 of Set 637 | matara
# Processing Record 268 of Set 637 | airai
# Processing Record 269 of Set 637 | beyla
# Processing Record 270 of Set 637 | adrar
# Processing Record 271 of Set 637 | karoi
# Processing Record 272 of Set 637 | omsukchan
# Processing Record 273 of Set 637 | rio verde de mato grosso
# Processing Record 274 of Set 637 | hamilton
# Processing Record 275 of Set 637 | barras
# Processing Record 276 of Set 637 | lagoa
# Processing Record 277 of Set 637 | kjollefjord
# Processing Record 278 of Set 637 | krasnovishersk
# Processing Record 279 of Set 637 | komsomolskiy
# Processing Record 280 of Set 637 | dien bien
# City not found. Skipping...
# Processing Record 281 of Set 637 | aklavik
# Processing Record 282 of Set 637 | tromso
# Processing Record 283 of Set 637 | chara
# Processing Record 284 of Set 637 | tautira
# Processing Record 285 of Set 637 | georgetown
# Processing Record 286 of Set 637 | linxia
# Processing Record 287 of Set 637 | palabuhanratu
# City not found. Skipping...
# Processing Record 288 of Set 637 | whitehorse
# Processing Record 289 of Set 637 | valdivia
# Processing Record 290 of Set 637 | labuhan
# Processing Record 291 of Set 637 | maciel
# Processing Record 292 of Set 637 | worland
# Processing Record 293 of Set 637 | chifeng
# Processing Record 294 of Set 637 | victoria
# Processing Record 295 of Set 637 | westport
# Processing Record 296 of Set 637 | grand river south east
# City not found. Skipping...
# Processing Record 297 of Set 637 | pointe-noire
# Processing Record 298 of Set 637 | calama
# Processing Record 299 of Set 637 | paratinga
# Processing Record 300 of Set 637 | yuncheng
# Processing Record 301 of Set 637 | araouane
# Processing Record 302 of Set 637 | ushtobe
# Processing Record 303 of Set 637 | ambon
# Processing Record 304 of Set 637 | mandera
# Processing Record 305 of Set 637 | lorengau
# Processing Record 306 of Set 637 | alcala la real
# Processing Record 307 of Set 637 | rajshahi
# Processing Record 308 of Set 637 | laukaa
# Processing Record 309 of Set 637 | gourcy
# Processing Record 310 of Set 637 | teluknaga
# Processing Record 311 of Set 637 | melbu
# Processing Record 312 of Set 637 | bac lieu
# City not found. Skipping...
# Processing Record 313 of Set 637 | hambantota
# Processing Record 314 of Set 637 | buta
# Processing Record 315 of Set 637 | delta del tigre
# Processing Record 316 of Set 637 | byron bay
# Processing Record 317 of Set 637 | sibolga
# Processing Record 318 of Set 637 | aflu
# City not found. Skipping...
# Processing Record 319 of Set 637 | los llanos de aridane
# Processing Record 320 of Set 637 | keelung
# Processing Record 321 of Set 637 | nanortalik
# Processing Record 322 of Set 637 | bubaque
# Processing Record 323 of Set 637 | maceio
# Processing Record 324 of Set 637 | clinton
# Processing Record 325 of Set 637 | phalaborwa
# Processing Record 326 of Set 637 | eyl
# Processing Record 327 of Set 637 | caravelas
# Processing Record 328 of Set 637 | wajima
# Processing Record 329 of Set 637 | miyako
# Processing Record 330 of Set 637 | tartki
# City not found. Skipping...
# Processing Record 331 of Set 637 | mount gambier
# Processing Record 332 of Set 637 | villaviciosa
# Processing Record 333 of Set 637 | khuzdar
# Processing Record 334 of Set 637 | batemans bay
# Processing Record 335 of Set 637 | ahuimanu
# Processing Record 336 of Set 637 | kimbe
# Processing Record 337 of Set 637 | talara
# Processing Record 338 of Set 637 | ust-kuyga
# Processing Record 339 of Set 637 | peniche
# Processing Record 340 of Set 637 | bolungarvik
# City not found. Skipping...
# Processing Record 341 of Set 637 | roma
# Processing Record 342 of Set 637 | montbrison
# Processing Record 343 of Set 637 | dakor
# Processing Record 344 of Set 637 | atar
# Processing Record 345 of Set 637 | storozhevaya
# Processing Record 346 of Set 637 | evansville
# Processing Record 347 of Set 637 | pacific grove
# Processing Record 348 of Set 637 | suntar
# Processing Record 349 of Set 637 | tocopilla
# Processing Record 350 of Set 637 | potosi
# Processing Record 351 of Set 637 | sidi qasim
# City not found. Skipping...
# Processing Record 352 of Set 637 | karatau
# Processing Record 353 of Set 637 | ruatoria
# City not found. Skipping...
# Processing Record 354 of Set 637 | kamaishi
# Processing Record 355 of Set 637 | santa marinella
# Processing Record 356 of Set 637 | jiddah
# City not found. Skipping...
# Processing Record 357 of Set 637 | lolua
# City not found. Skipping...
# Processing Record 358 of Set 637 | cairns
# Processing Record 359 of Set 637 | ambulu
# Processing Record 360 of Set 637 | virginia beach
# Processing Record 361 of Set 637 | namatanai
# Processing Record 362 of Set 637 | ryuo
# Processing Record 363 of Set 637 | tuatapere
# Processing Record 364 of Set 637 | belmonte
# Processing Record 365 of Set 637 | llanes
# Processing Record 366 of Set 637 | kommunisticheskiy
# Processing Record 367 of Set 637 | erenhot
# Processing Record 368 of Set 637 | palmer
# Processing Record 369 of Set 637 | havelock
# Processing Record 370 of Set 637 | northam
# Processing Record 371 of Set 637 | tugulym
# Processing Record 372 of Set 637 | lipin bor
# Processing Record 373 of Set 637 | ye
# City not found. Skipping...
# Processing Record 374 of Set 637 | iaciara
# Processing Record 375 of Set 637 | makakilo city
# Processing Record 376 of Set 637 | wanning
# Processing Record 377 of Set 637 | yerbogachen
# Processing Record 378 of Set 637 | tsihombe
# City not found. Skipping...
# Processing Record 379 of Set 637 | avera
# Processing Record 380 of Set 637 | hovd
# Processing Record 381 of Set 637 | zhanaozen
# Processing Record 382 of Set 637 | lovozero
# Processing Record 383 of Set 637 | lumsden
# Processing Record 384 of Set 637 | mavelikara
# Processing Record 385 of Set 637 | nagorsk
# Processing Record 386 of Set 637 | asayita
# City not found. Skipping...
# Processing Record 387 of Set 637 | barawe
# City not found. Skipping...
# Processing Record 388 of Set 637 | pangoa
# Processing Record 389 of Set 637 | severo-kurilsk
# Processing Record 390 of Set 637 | puerto varas
# Processing Record 391 of Set 637 | morgan city
# Processing Record 392 of Set 637 | trinidad
# Processing Record 393 of Set 637 | constitucion
# Processing Record 394 of Set 637 | kuytun
# Processing Record 395 of Set 637 | axixa do tocantins
# City not found. Skipping...
# Processing Record 396 of Set 637 | skibbereen
# Processing Record 397 of Set 637 | riyadh
# Processing Record 398 of Set 637 | elizabeth city
# Processing Record 399 of Set 637 | kathu
# Processing Record 400 of Set 637 | priupskiy
# Processing Record 401 of Set 637 | longyearbyen
# Processing Record 402 of Set 637 | russkaya polyana
# Processing Record 403 of Set 637 | kariba
# Processing Record 404 of Set 637 | osorno
# Processing Record 405 of Set 637 | grahamstown
# Processing Record 406 of Set 637 | poso
# Processing Record 407 of Set 637 | berdigestyakh
# Processing Record 408 of Set 637 | norman wells
# Processing Record 409 of Set 637 | fort nelson
# Processing Record 410 of Set 637 | semey
# Processing Record 411 of Set 637 | marsh harbour
# Processing Record 412 of Set 637 | mapiripan
# Processing Record 413 of Set 637 | polczyn-zdroj
# Processing Record 414 of Set 637 | chicama
# Processing Record 415 of Set 637 | salaga
# Processing Record 416 of Set 637 | salinas
# Processing Record 417 of Set 637 | bondoukou
# Processing Record 418 of Set 637 | mendoza
# Processing Record 419 of Set 637 | mendahara
# City not found. Skipping...
# Processing Record 420 of Set 637 | duncan
# Processing Record 421 of Set 637 | yumen
# Processing Record 422 of Set 637 | saint-leu
# Processing Record 423 of Set 637 | port lincoln
# Processing Record 424 of Set 637 | leningradskiy
# Processing Record 425 of Set 637 | zhuzhou
# Processing Record 426 of Set 637 | savelugu
# Processing Record 427 of Set 637 | samana
# Processing Record 428 of Set 637 | faanui
# Processing Record 429 of Set 637 | alice springs
# Processing Record 430 of Set 637 | vestmanna
# Processing Record 431 of Set 637 | berga
# Processing Record 432 of Set 637 | waddan
# Processing Record 433 of Set 637 | san lorenzo
# Processing Record 434 of Set 637 | te anau
# Processing Record 435 of Set 637 | nantucket
# Processing Record 436 of Set 637 | fort collins
# Processing Record 437 of Set 637 | clyde river
# Processing Record 438 of Set 637 | brae
# Processing Record 439 of Set 637 | pestravka
# Processing Record 440 of Set 637 | iskateley
# Processing Record 441 of Set 637 | marsabit
# Processing Record 442 of Set 637 | sao filipe
# Processing Record 443 of Set 637 | santa cruz del sur
# Processing Record 444 of Set 637 | richards bay
# Processing Record 445 of Set 637 | homer
# Processing Record 446 of Set 637 | ilo
# Processing Record 447 of Set 637 | laguna de perlas
# Processing Record 448 of Set 637 | lompoc
# Processing Record 449 of Set 637 | coquimbo
# Processing Record 450 of Set 637 | asau
# City not found. Skipping...
# Processing Record 451 of Set 637 | okhotsk
# Processing Record 452 of Set 637 | coahuayana
# Processing Record 453 of Set 637 | vaitupu
# City not found. Skipping...
# Processing Record 454 of Set 637 | angoche
# Processing Record 455 of Set 637 | keti bandar
# Processing Record 456 of Set 637 | anchorage
# Processing Record 457 of Set 637 | barbar
# City not found. Skipping...
# Processing Record 458 of Set 637 | ishigaki
# Processing Record 459 of Set 637 | auki
# Processing Record 460 of Set 637 | columbia
# Processing Record 461 of Set 637 | el alto
# Processing Record 462 of Set 637 | stykkisholmur
# Processing Record 463 of Set 637 | mitsamiouli
# Processing Record 464 of Set 637 | okato
# Processing Record 465 of Set 637 | olafsvik
# City not found. Skipping...
# Processing Record 466 of Set 637 | hartselle
# Processing Record 467 of Set 637 | karamea
# City not found. Skipping...
# Processing Record 468 of Set 637 | mvuma
# Processing Record 469 of Set 637 | lata
# Processing Record 470 of Set 637 | kropotkin
# Processing Record 471 of Set 637 | rocha
# Processing Record 472 of Set 637 | dryden
# Processing Record 473 of Set 637 | narrabri
# Processing Record 474 of Set 637 | oktyabrskoye
# Processing Record 475 of Set 637 | kudahuvadhoo
# Processing Record 476 of Set 637 | qaqortoq
# Processing Record 477 of Set 637 | kuche
# City not found. Skipping...
# Processing Record 478 of Set 637 | mao
# Processing Record 479 of Set 637 | tingo maria
# Processing Record 480 of Set 637 | rio grande
# Processing Record 481 of Set 637 | nouadhibou
# Processing Record 482 of Set 637 | port-de-paix
# City not found. Skipping...
# Processing Record 483 of Set 637 | alta floresta
# Processing Record 484 of Set 637 | buluang
# Processing Record 485 of Set 637 | cabedelo
# Processing Record 486 of Set 637 | sibucao
# Processing Record 487 of Set 637 | marzuq
# Processing Record 488 of Set 637 | bangassou
# Processing Record 489 of Set 637 | ancud
# Processing Record 490 of Set 637 | korla
# City not found. Skipping...
# Processing Record 491 of Set 637 | balestrand
# Processing Record 492 of Set 637 | denpasar
# Processing Record 493 of Set 637 | marsa matruh
# Processing Record 494 of Set 637 | sao felix do xingu
# Processing Record 495 of Set 637 | auch
# Processing Record 496 of Set 637 | gornopravdinsk
# Processing Record 497 of Set 637 | iqaluit
# Processing Record 498 of Set 637 | bengkulu
# City not found. Skipping...
# Processing Record 499 of Set 637 | bhuvanagiri
# Processing Record 500 of Set 637 | henties bay
# Processing Record 501 of Set 637 | kattivakkam
# Processing Record 502 of Set 637 | necochea
# Processing Record 503 of Set 637 | dali
# Processing Record 504 of Set 637 | carutapera
# Processing Record 505 of Set 637 | el cope
# Processing Record 506 of Set 637 | la rochelle
# Processing Record 507 of Set 637 | calais
# Processing Record 508 of Set 637 | spornoye
# Processing Record 509 of Set 637 | khorixas
# Processing Record 510 of Set 637 | faya
# Processing Record 511 of Set 637 | vila velha
# Processing Record 512 of Set 637 | rehau
# Processing Record 513 of Set 637 | vao
# Processing Record 514 of Set 637 | lages
# Processing Record 515 of Set 637 | anadyr
# Processing Record 516 of Set 637 | chinna salem
# Processing Record 517 of Set 637 | marcona
# City not found. Skipping...
# Processing Record 518 of Set 637 | coihaique
# Processing Record 519 of Set 637 | podgornoye
# Processing Record 520 of Set 637 | indianola
# Processing Record 521 of Set 637 | lieksa
# Processing Record 522 of Set 637 | gorodets
# Processing Record 523 of Set 637 | dingle
# Processing Record 524 of Set 637 | almeirim
# Processing Record 525 of Set 637 | hami
# Processing Record 526 of Set 637 | westbury
# Processing Record 527 of Set 637 | luba
# Processing Record 528 of Set 637 | pak phanang
# Processing Record 529 of Set 637 | pochutla
# Processing Record 530 of Set 637 | victor harbor
# Processing Record 531 of Set 637 | nagato
# Processing Record 532 of Set 637 | voskresenskoye
# Processing Record 533 of Set 637 | ust-tsilma
# Processing Record 534 of Set 637 | mezen
# Processing Record 535 of Set 637 | seymchan
# Processing Record 536 of Set 637 | panguna
# Processing Record 537 of Set 637 | port hedland
# Processing Record 538 of Set 637 | touros
# Processing Record 539 of Set 637 | salym
# Processing Record 540 of Set 637 | januaria
# City not found. Skipping...
# Processing Record 541 of Set 637 | grindavik
# Processing Record 542 of Set 637 | salta
# Processing Record 543 of Set 637 | horta
# Processing Record 544 of Set 637 | cascais
# Processing Record 545 of Set 637 | padang
# Processing Record 546 of Set 637 | kaeo
# Processing Record 547 of Set 637 | atambua
# Processing Record 548 of Set 637 | leh
# Processing Record 549 of Set 637 | beloha
# Processing Record 550 of Set 637 | mareeba
# Processing Record 551 of Set 637 | rimouski
# Processing Record 552 of Set 637 | kavaratti
# Processing Record 553 of Set 637 | botou
# Processing Record 554 of Set 637 | yamada
# Processing Record 555 of Set 637 | truckee
# Processing Record 556 of Set 637 | verkhnyaya toyma
# Processing Record 557 of Set 637 | chuy
# Processing Record 558 of Set 637 | tabuk
# Processing Record 559 of Set 637 | kushiro
# Processing Record 560 of Set 637 | ziarat
# Processing Record 561 of Set 637 | salina
# Processing Record 562 of Set 637 | khani
# Processing Record 563 of Set 637 | hvide sande
# Processing Record 564 of Set 637 | soyo
# Processing Record 565 of Set 637 | la colorada
# Processing Record 566 of Set 637 | mirante do paranapanema
# Processing Record 567 of Set 637 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 568 of Set 637 | itaberaba
# Processing Record 569 of Set 637 | ukiah
# Processing Record 570 of Set 637 | nedumangad
# Processing Record 571 of Set 637 | tongliao
# Processing Record 572 of Set 637 | kirkwall
# Processing Record 573 of Set 637 | acajutla
# Processing Record 574 of Set 637 | comodoro rivadavia
# Processing Record 575 of Set 637 | karachi
# Processing Record 576 of Set 637 | vostok
# Processing Record 577 of Set 637 | samarai
# Processing Record 578 of Set 637 | rio pomba
# Processing Record 579 of Set 637 | puerto plata
# Processing Record 580 of Set 637 | tianjin
# Processing Record 581 of Set 637 | culebra
# Processing Record 582 of Set 637 | arlit
# Processing Record 583 of Set 637 | olhao
# Processing Record 584 of Set 637 | sonepur
# Processing Record 585 of Set 637 | topolovgrad
# Processing Record 586 of Set 637 | pimentel
# Processing Record 587 of Set 637 | sao miguel do araguaia
# Processing Record 588 of Set 637 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 589 of Set 637 | yaan
# Processing Record 590 of Set 637 | ewa beach
# Processing Record 591 of Set 637 | ingham
# Processing Record 592 of Set 637 | mahaicony
# City not found. Skipping...
# Processing Record 593 of Set 637 | ulladulla
# Processing Record 594 of Set 637 | salmo
# Processing Record 595 of Set 637 | rundu
# Processing Record 596 of Set 637 | killybegs
# Processing Record 597 of Set 637 | oeiras do para
# Processing Record 598 of Set 637 | revda
# Processing Record 599 of Set 637 | ntoum
# Processing Record 600 of Set 637 | fayaoue
# Processing Record 601 of Set 637 | aliwal north
# Processing Record 602 of Set 637 | bhimunipatnam
# Processing Record 603 of Set 637 | soeng sang
# Processing Record 604 of Set 637 | hihifo
# City not found. Skipping...
# Processing Record 605 of Set 637 | tagusao
# Processing Record 606 of Set 637 | luanda
# Processing Record 607 of Set 637 | maarianhamina
# City not found. Skipping...
# Processing Record 608 of Set 637 | benito juarez
# Processing Record 609 of Set 637 | zheleznodorozhnyy
# Processing Record 610 of Set 637 | iroquois falls
# Processing Record 611 of Set 637 | chiredzi
# Processing Record 612 of Set 637 | mecca
# Processing Record 613 of Set 637 | urumqi
# City not found. Skipping...
# Processing Record 614 of Set 637 | mehamn
# Processing Record 615 of Set 637 | najran
# Processing Record 616 of Set 637 | russell
# Processing Record 617 of Set 637 | mungwi
# Processing Record 618 of Set 637 | swellendam
# Processing Record 619 of Set 637 | camacari
# Processing Record 620 of Set 637 | mahanoro
# Processing Record 621 of Set 637 | oudtshoorn
# Processing Record 622 of Set 637 | chermoz
# Processing Record 623 of Set 637 | xiongshi
# City not found. Skipping...
# Processing Record 624 of Set 637 | trabzon
# Processing Record 625 of Set 637 | tura
# Processing Record 626 of Set 637 | ust-kulom
# Processing Record 627 of Set 637 | schkeuditz
# Processing Record 628 of Set 637 | yenagoa
# Processing Record 629 of Set 637 | umm lajj
# Processing Record 630 of Set 637 | ninghai
# Processing Record 631 of Set 637 | breves
# Processing Record 632 of Set 637 | arti
# Processing Record 633 of Set 637 | sabha
# Processing Record 634 of Set 637 | kudat
# Processing Record 635 of Set 637 | bushehr
# Processing Record 636 of Set 637 | pemberton
# Processing Record 637 of Set 637 | culaman
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#                 City Cloudiness Country        Date Max Temp Wind Speed  \
# 0        New Norfolk          0      AU  1544016600   286.15          1
# 1              Vaini         75      IN  1544014800   296.15        1.5
# 2          Cape Town         88      ZA  1544017801  292.306       4.42
# 3  Praxedis Guerrero         40      MX  1544014680   278.15        4.1
# 4           Khatanga         88      RU  1544017868  255.206       8.27
#
#      Lat     Lng Humidity
# 0 -42.78  147.06       82
# 1  15.34   74.49       94
# 2 -33.93   18.42       85
# 3  31.37 -106.02       44
# 4  71.98  102.47       78

# %%
df.count()
# Out:
# City          575
# Cloudiness    575
# Country       575
# Date          575
# Max Temp      575
# Wind Speed    575
# Lat           575
# Lng           575
# Humidity      575
# dtype: int64

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
import seaborn as sns
from datetime import datetime
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(df["Lat"], df["Max Temp"], color='b', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(df["Lat"], df["Humidity"], color='b', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(df["Lat"], df["Cloudiness"], color='b', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(df["Lat"], df["Wind Speed"], color='b', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()
